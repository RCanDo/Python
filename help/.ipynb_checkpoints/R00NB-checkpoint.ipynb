# %%
xx <- 1:10

# %%
yy <- xx + rnorm(10,0,1)

# %%
mod <- lm( yy ~ xx )

# %%
summary(mod)
# Out:
# Call:
# lm(formula = yy ~ xx)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.2646 -0.5503 -0.0301  0.4449  1.6026
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.51530    0.59363  -0.868    0.411
# xx           1.06535    0.09567  11.135 3.78e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.869 on 8 degrees of freedom
# Multiple R-squared:  0.9394,	Adjusted R-squared:  0.9318
# F-statistic:   124 on 1 and 8 DF,  p-value: 3.783e-06

# %%
plot(mod)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
plot( yy ~ xx )
abline(mod$coef)
# Out:
# plot without title
